# %%
import matplotlib.pyplot as plt

# %%
x=["python","c++","c","java"]
y=[85,40,50,30]
color=['m','r','b','g']
plt.bar(x,y,color='r',label="average",edgecolor='y',alpha=0.6)
plt.legend()
plt.title("bar plot")
plt.xlabel('x_axis')
plt.ylabel("y_axis")
plt.show()
