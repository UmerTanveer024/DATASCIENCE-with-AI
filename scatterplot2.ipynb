# %%
import matplotlib.pyplot as plt

# %%
x=[1,2,3,4,5]
y=[50,60,70,20,30]
plt.scatter(x,y)
#plt.title("Result",fontsize=60,color='r')
plt.suptitle("My scatter plot",fontsize=15)
plt.title("value",y=0.9,x=0.4)
plt.show()
