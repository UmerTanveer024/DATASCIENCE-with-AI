# %%
import numpy as np
import matplotlib.pyplot as plt
import random

# %%
np.random.rand(1,50,(80))
# Out:
# array([[[0.20431696, 0.57430639, 0.15639885, ..., 0.13099735,
#          0.96101497, 0.97056236],
#         [0.97842421, 0.5222421 , 0.70936642, ..., 0.03745829,
#          0.50627343, 0.33645929],
#         [0.07765352, 0.77128272, 0.24348018, ..., 0.04440199,
#          0.63783873, 0.26094123],
#         ...,
#         [0.60703204, 0.77316292, 0.63459554, ..., 0.43311162,
#          0.75929409, 0.77560422],
#         [0.21087758, 0.83786874, 0.60009421, ..., 0.32878068,
#          0.23314831, 0.39482164],
#         [0.85057875, 0.758785  , 0.60210083, ..., 0.14766991,
#          0.40773276, 0.8269367 ]]])

# %%
np.random.randint(1,50,(80))
# Out:
# array([49, 40, 17, 18, 29, 27, 46, 26, 34, 36, 24, 41,  2, 31, 25, 14, 14,
#        13, 28, 49, 49,  1, 32,  3, 10,  3,  2, 34,  1, 44, 29, 28, 31, 26,
#        49, 29,  5,  4, 11, 23, 23, 18, 28, 30, 24, 43,  2,  5, 40, 46, 30,
#        13, 12, 39,  5,  2, 48, 49, 18, 37, 42, 47, 37,  3,  8,  6, 42, 26,
#        19, 27, 35, 20, 12, 20, 19,  4, 32, 13, 17,  4])

# %%
x=[19, 41, 29, 20, 35, 12,  3, 42, 26, 30,  6, 21, 42, 18,  9, 25, 31,
       26, 46, 10, 33, 30, 26, 17, 36,  7, 14, 37, 28, 33, 17, 15,  5, 18,
       47, 19, 13, 38, 20, 39,  8, 21,  2,  6, 37, 14, 39, 15, 21,  8, 30,
       35,  6,  9,  3, 23, 25,  4,  4, 38, 44, 39, 12,  5, 11, 23,  5, 27,
       30, 36, 39,  5, 42, 16, 13, 48,  9,  8, 47, 48]
print(x)
#plt.hist(x)
#plt.show()
# Out:
# [19, 41, 29, 20, 35, 12, 3, 42, 26, 30, 6, 21, 42, 18, 9, 25, 31, 26, 46, 10, 33, 30, 26, 17, 36, 7, 14, 37, 28, 33, 17, 15, 5, 18, 47, 19, 13, 38, 20, 39, 8, 21, 2, 6, 37, 14, 39, 15, 21, 8, 30, 35, 6, 9, 3, 23, 25, 4, 4, 38, 44, 39, 12, 5, 11, 23, 5, 27, 30, 36, 39, 5, 42, 16, 13, 48, 9, 8, 47, 48]

# %%
#plt.hist(x,color='y',range=(0,200))
#plt.title("Histogram",color='r')
#plt.xlabel("x_axis",color='r')
#plt.ylabel("y_axis",color='y')
#plt.show()

# %%
#plt.hist(x,color='y',range=(0,300),cumulative=-1,bottom=10,orientation="horizontal")
#plt.title("Histogram",color='r')
#plt.xlabel("x_axis",color='r')
#plt.ylabel("y_axis",color='y')
#plt.show()

# %%
#plt.hist(x,color='y',range=(0,300),cumulative=-1,bottom=10,histtype="step")
#plt.hist(x,color='y',range=(0,300),cumulative=-1,bottom=10,histtype="stepfilled")
#plt.hist(x,color='y',range=(0,300),cumulative=-1,bottom=10,histtype="barstacked")
#plt.hist(x,color='y',range=(0,300),cumulative=-1,bottom=10,histtype="bar")
#plt.hist(x,color='y',range=(0,300),cumulative=-1,bottom=10,rwidth=0.6)
#plt.hist(x,color='y',range=(0,300),cumulative=-1,bottom=10,rwidth=0.6,log=True)
#plt.hist(x,color='y',range=(0,300),cumulative=-1,bottom=10,rwidth=0.6,log=True,label="numerical data")
#plt.legend()
plt.hist(x,color='y',range=(0,300),cumulative=-1,bottom=10,rwidth=0.6,log=True,label="numerical data")
#plt.legend()
plt.axvline(40,color='g',label="average")
plt.legend()
plt.title("Histogram",color='r')
plt.xlabel("x_axis",color='r')
plt.ylabel("y_axis",color='y')
plt.show()
